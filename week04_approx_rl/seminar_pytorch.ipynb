# %% [markdown]
# # Approximate q-learning
#
# In this notebook you will teach a __PyTorch__ neural network to do Q-learning.

# %%
import sys, os
if 'google.colab' in sys.modules and not os.path.exists('.setup_complete'):
    # !wget -q https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/setup_colab.sh -O- | bash
    # !touch .setup_complete

# This code creates a virtual display to draw game images on.
# It will have no effect if your machine has a monitor.
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY")) == 0:
    # !bash ../xvfb start
    os.environ['DISPLAY'] = ':1'

# %%
import gym
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
env = gym.make("CartPole-v0").env
env.reset()
n_actions = env.action_space.n
state_dim = env.observation_space.shape

plt.imshow(env.render("rgb_array"))
env.close()

# %% [markdown]
# # Approximate Q-learning: building the network
#
# To train a neural network policy one must have a neural network policy. Let's build it.
#
#
# Since we're working with a pre-extracted features (cart positions, angles and velocities), we don't need a complicated network yet. In fact, let's build something like this for starters:
#
# ![img](https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/yet_another_week/_resource/qlearning_scheme.png)
#
# For your first run, please only use linear layers (`nn.Linear`) and activations. Stuff like batch normalization or dropout may ruin everything if used haphazardly.
#
# Also please avoid using nonlinearities like sigmoid & tanh: since agent's observations are not normalized, sigmoids might be saturated at initialization. Instead, use non-saturating nonlinearities like ReLU.
#
# Ideally you should start small with maybe 1-2 hidden layers with < 200 neurons and then increase network size if agent doesn't beat the target score.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
network = nn.Sequential()

network.add_module('layer1', nn.Linear(state_dim[0], 128))

# network.add_module('layer2', nn.Linear(128, 128))
network.add_module('layer3', nn.Linear(128, 2))
# <YOUR CODE: stack layers!!!1>

# hint: use state_dim[0] as input size

# %%
def get_action(state, epsilon=0):
    """
    sample actions with epsilon-greedy policy
    recap: with p = epsilon pick random action, else pick action with highest Q(s,a)
    """
    state = torch.tensor(state[None], dtype=torch.float32)
    q_values = network(state).detach().numpy()
    # q_values = network.predict(state[None])[0]

    # <YOUR CODE>
    # epsilon-greedy policy
    a = np.argmax(q_values) if np.random.random() > epsilon else np.random.randint(n_actions)
    

    return int( a )

# %%
s = env.reset()

assert tuple(network(torch.tensor([s]*3, dtype=torch.float32)).size()) == (
    3, n_actions), "please make sure your model maps state s -> [Q(s,a0), ..., Q(s, a_last)]"
assert isinstance(list(network.modules(
))[-1], nn.Linear), "please make sure you predict q-values without nonlinearity (ignore if you know what you're doing)"
assert isinstance(get_action(
    s), int), "get_action(s) must return int, not %s. try int(action)" % (type(get_action(s)))

# test epsilon-greedy exploration
for eps in [0., 0.1, 0.5, 1.0]:
    state_frequencies = np.bincount(
        [get_action(s, epsilon=eps) for i in range(10000)], minlength=n_actions)
    best_action = state_frequencies.argmax()
    assert abs(state_frequencies[best_action] - 10000 * (1 - eps + eps / n_actions)) < 200
    for other_action in range(n_actions):
        if other_action != best_action:
            assert abs(state_frequencies[other_action] - 10000 * (eps / n_actions)) < 200
    print('e=%.1f tests passed' % eps)
# Out:
# e=0.0 tests passed
# e=0.1 tests passed
# e=0.5 tests passed
# e=1.0 tests passed

# %% [markdown]
# ### Q-learning via gradient descent
#
# We shall now train our agent's Q-function by minimizing the TD loss:
# $$ L = { 1 \over N} \sum_i (Q_{\theta}(s,a) - [r(s,a) + \gamma \cdot max_{a'} Q_{-}(s', a')]) ^2 $$
#
#
# Where
# * $s, a, r, s'$ are current state, action, reward and next state respectively
# * $\gamma$ is a discount factor defined two cells above.
#
# The tricky part is with  $Q_{-}(s',a')$. From an engineering standpoint, it's the same as $Q_{\theta}$ - the output of your neural network policy. However, when doing gradient descent, __we won't propagate gradients through it__ to make training more stable (see lectures).
#
# To do so, we shall use `x.detach()` function which basically says "consider this thing constant when doingbackprop".

# %%
def compute_td_loss(states, actions, rewards, next_states, is_done, gamma=0.99, check_shapes=False):
    """ Compute td loss using torch operations only. Use the formula above. """
    states = torch.tensor(
        states, dtype=torch.float32)                                  # shape: [batch_size, state_size]
    actions = torch.tensor(actions, dtype=torch.long)                 # shape: [batch_size]
    rewards = torch.tensor(rewards, dtype=torch.float32)              # shape: [batch_size]
    # shape: [batch_size, state_size]
    next_states = torch.tensor(next_states, dtype=torch.float32)
    is_done = torch.tensor(is_done, dtype=torch.uint8)                # shape: [batch_size]

    # get q-values for all actions in current states
    predicted_qvalues = network(states)                               # shape: [batch_size, n_actions]

    # select q-values for chosen actions
    predicted_qvalues_for_actions = predicted_qvalues[                # shape: [batch_size]
      range(states.shape[0]), actions
    ]

    # compute q-values for all actions in next states
    predicted_next_qvalues = network(next_states.detach()) # <YOUR CODE>

    # compute V*(next_states) using predicted next q-values
    next_state_values = torch.max(predicted_next_qvalues, 1)[0] #<YOUR CODE>
    assert next_state_values.dtype == torch.float32

    # compute "target q-values" for loss - it's what's inside square parentheses in the above formula.
    target_qvalues_for_actions = rewards + gamma * next_state_values  # <YOUR CODE>

    # at the last state we shall use simplified formula: Q(s,a) = r(s,a) since s' doesn't exist
    target_qvalues_for_actions = torch.where(
        is_done, rewards, target_qvalues_for_actions)

    # mean squared error loss to minimize
    loss = torch.mean((predicted_qvalues_for_actions -
                       target_qvalues_for_actions.detach()) ** 2)

    if check_shapes:
        assert predicted_next_qvalues.data.dim(
        ) == 2, "make sure you predicted q-values for all actions in next state"
        assert next_state_values.data.dim(
        ) == 1, "make sure you computed V(s') as maximum over just the actions axis and not all axes"
        assert target_qvalues_for_actions.data.dim(
        ) == 1, "there's something wrong with target q-values, they must be a vector"

    return loss

# %%
# sanity checks
s = env.reset()
a = env.action_space.sample()
next_s, r, done, _ = env.step(a)
loss = compute_td_loss([s], [a], [r], [next_s], [done], check_shapes=True)
loss.backward()

assert len(loss.size()) == 0, "you must return scalar loss - mean over batch"
assert np.any(next(network.parameters()).grad.detach().numpy() !=
              0), "loss must be differentiable w.r.t. network weights"

# %% [markdown]
# ### Playing the game

# %%
opt = torch.optim.Adam(network.parameters(), lr=1e-4)

# %%
def generate_session(env, t_max=1000, epsilon=0, train=False):
    """play env with approximate q-learning agent and train it at the same time"""
    total_reward = 0
    s = env.reset()

    for t in range(t_max):
        a = get_action(s, epsilon=epsilon)
        next_s, r, done, _ = env.step(a)

        if train:
            opt.zero_grad()
            compute_td_loss([s], [a], [r], [next_s], [done]).backward()
            opt.step()

        total_reward += r
        s = next_s
        if done:
            break

    return total_reward

# %%
epsilon = 0.25

# %%
for i in range(1000):
    session_rewards = [generate_session(env, epsilon=epsilon, train=True) for _ in range(100)]
    print("epoch #{}\tmean reward = {:.3f}\tepsilon = {:.3f}".format(i, np.mean(session_rewards), epsilon))

    epsilon *= 0.99
    assert epsilon >= 1e-4, "Make sure epsilon is always nonzero during training"

    if np.mean(session_rewards) > 300:
        print("You Win!")
        break
# Out:
# epoch #0	mean reward = 10.880	epsilon = 0.250
# epoch #1	mean reward = 10.940	epsilon = 0.247
# epoch #2	mean reward = 10.620	epsilon = 0.245
# epoch #3	mean reward = 10.910	epsilon = 0.243
# epoch #4	mean reward = 10.550	epsilon = 0.240
# epoch #5	mean reward = 10.620	epsilon = 0.238
# epoch #6	mean reward = 10.620	epsilon = 0.235
# epoch #7	mean reward = 11.250	epsilon = 0.233
# epoch #8	mean reward = 13.400	epsilon = 0.231
# epoch #9	mean reward = 27.220	epsilon = 0.228
# epoch #10	mean reward = 16.710	epsilon = 0.226
# epoch #11	mean reward = 15.220	epsilon = 0.224
# epoch #12	mean reward = 28.380	epsilon = 0.222
# epoch #13	mean reward = 12.890	epsilon = 0.219
# epoch #14	mean reward = 12.100	epsilon = 0.217
# epoch #15	mean reward = 17.650	epsilon = 0.215
# epoch #16	mean reward = 10.720	epsilon = 0.213
# epoch #17	mean reward = 10.760	epsilon = 0.211
# epoch #18	mean reward = 14.610	epsilon = 0.209
# epoch #19	mean reward = 13.000	epsilon = 0.207
# epoch #20	mean reward = 10.300	epsilon = 0.204
# epoch #21	mean reward = 10.840	epsilon = 0.202
# epoch #22	mean reward = 11.930	epsilon = 0.200
# epoch #23	mean reward = 12.350	epsilon = 0.198
# epoch #24	mean reward = 10.250	epsilon = 0.196
# epoch #25	mean reward = 10.310	epsilon = 0.194
# epoch #26	mean reward = 10.940	epsilon = 0.193
# epoch #27	mean reward = 16.620	epsilon = 0.191
# epoch #28	mean reward = 10.330	epsilon = 0.189
# epoch #29	mean reward = 10.430	epsilon = 0.187
# epoch #30	mean reward = 10.700	epsilon = 0.185
# epoch #31	mean reward = 14.420	epsilon = 0.183
# epoch #32	mean reward = 10.430	epsilon = 0.181
# epoch #33	mean reward = 10.490	epsilon = 0.179
# epoch #34	mean reward = 10.210	epsilon = 0.178
# epoch #35	mean reward = 14.630	epsilon = 0.176
# epoch #36	mean reward = 11.440	epsilon = 0.174
# epoch #37	mean reward = 10.340	epsilon = 0.172
# epoch #38	mean reward = 10.350	epsilon = 0.171
# epoch #39	mean reward = 10.930	epsilon = 0.169
# epoch #40	mean reward = 14.040	epsilon = 0.167
# epoch #41	mean reward = 10.530	epsilon = 0.166
# epoch #42	mean reward = 10.240	epsilon = 0.164
# epoch #43	mean reward = 10.080	epsilon = 0.162
# epoch #44	mean reward = 15.690	epsilon = 0.161
# epoch #45	mean reward = 10.150	epsilon = 0.159
# epoch #46	mean reward = 10.170	epsilon = 0.157
# epoch #47	mean reward = 10.440	epsilon = 0.156
# epoch #48	mean reward = 11.040	epsilon = 0.154
# epoch #49	mean reward = 15.730	epsilon = 0.153
# epoch #50	mean reward = 10.300	epsilon = 0.151
# epoch #51	mean reward = 10.320	epsilon = 0.150
# epoch #52	mean reward = 10.550	epsilon = 0.148
# epoch #53	mean reward = 16.260	epsilon = 0.147
# epoch #54	mean reward = 10.200	epsilon = 0.145
# epoch #55	mean reward = 10.170	epsilon = 0.144
# epoch #56	mean reward = 10.850	epsilon = 0.142
# epoch #57	mean reward = 15.920	epsilon = 0.141
# epoch #58	mean reward = 10.050	epsilon = 0.140
# epoch #59	mean reward = 10.170	epsilon = 0.138
# epoch #60	mean reward = 10.720	epsilon = 0.137
# epoch #61	mean reward = 17.230	epsilon = 0.135
# epoch #62	mean reward = 9.990	epsilon = 0.134
# epoch #63	mean reward = 10.250	epsilon = 0.133
# epoch #64	mean reward = 13.550	epsilon = 0.131
# epoch #65	mean reward = 13.450	epsilon = 0.130
# epoch #66	mean reward = 10.000	epsilon = 0.129
# epoch #67	mean reward = 10.190	epsilon = 0.127
# epoch #68	mean reward = 13.200	epsilon = 0.126
# epoch #69	mean reward = 14.500	epsilon = 0.125
# epoch #70	mean reward = 9.990	epsilon = 0.124
# epoch #71	mean reward = 9.970	epsilon = 0.122
# epoch #72	mean reward = 13.710	epsilon = 0.121
# epoch #73	mean reward = 12.730	epsilon = 0.120
# epoch #74	mean reward = 10.140	epsilon = 0.119
# epoch #75	mean reward = 9.870	epsilon = 0.118
# epoch #76	mean reward = 17.780	epsilon = 0.116
# epoch #77	mean reward = 10.890	epsilon = 0.115
# epoch #78	mean reward = 9.910	epsilon = 0.114
# epoch #79	mean reward = 10.700	epsilon = 0.113
# epoch #80	mean reward = 16.470	epsilon = 0.112
# epoch #81	mean reward = 9.760	epsilon = 0.111
# epoch #82	mean reward = 10.090	epsilon = 0.110
# epoch #83	mean reward = 20.180	epsilon = 0.109
# epoch #84	mean reward = 11.570	epsilon = 0.107
# epoch #85	mean reward = 9.720	epsilon = 0.106
# epoch #86	mean reward = 11.170	epsilon = 0.105
# epoch #87	mean reward = 17.760	epsilon = 0.104
# epoch #88	mean reward = 9.880	epsilon = 0.103
# epoch #89	mean reward = 9.560	epsilon = 0.102
# epoch #90	mean reward = 18.940	epsilon = 0.101
# epoch #91	mean reward = 10.260	epsilon = 0.100
# epoch #92	mean reward = 9.820	epsilon = 0.099
# epoch #93	mean reward = 11.420	epsilon = 0.098
# epoch #94	mean reward = 17.420	epsilon = 0.097
# epoch #95	mean reward = 9.970	epsilon = 0.096
# epoch #96	mean reward = 10.990	epsilon = 0.095
# epoch #97	mean reward = 20.870	epsilon = 0.094
# epoch #98	mean reward = 9.920	epsilon = 0.093
# epoch #99	mean reward = 10.460	epsilon = 0.092
# epoch #100	mean reward = 16.580	epsilon = 0.092
# epoch #101	mean reward = 9.760	epsilon = 0.091
# epoch #102	mean reward = 9.880	epsilon = 0.090
# epoch #103	mean reward = 18.620	epsilon = 0.089
# epoch #104	mean reward = 10.400	epsilon = 0.088
# epoch #105	mean reward = 9.990	epsilon = 0.087
# epoch #106	mean reward = 16.730	epsilon = 0.086
# epoch #107	mean reward = 10.600	epsilon = 0.085
# epoch #108	mean reward = 9.830	epsilon = 0.084
# epoch #109	mean reward = 11.250	epsilon = 0.084
# epoch #110	mean reward = 16.540	epsilon = 0.083
# epoch #111	mean reward = 9.860	epsilon = 0.082
# epoch #112	mean reward = 10.470	epsilon = 0.081
# epoch #113	mean reward = 17.780	epsilon = 0.080
# epoch #114	mean reward = 9.570	epsilon = 0.079
# epoch #115	mean reward = 10.570	epsilon = 0.079
# epoch #116	mean reward = 19.600	epsilon = 0.078
# epoch #117	mean reward = 9.700	epsilon = 0.077
# epoch #118	mean reward = 11.690	epsilon = 0.076
# epoch #119	mean reward = 17.140	epsilon = 0.076
# epoch #120	mean reward = 9.650	epsilon = 0.075
# epoch #121	mean reward = 10.580	epsilon = 0.074
# epoch #122	mean reward = 19.070	epsilon = 0.073
# epoch #123	mean reward = 9.660	epsilon = 0.073
# epoch #124	mean reward = 10.300	epsilon = 0.072
# epoch #125	mean reward = 18.340	epsilon = 0.071
# epoch #126	mean reward = 9.670	epsilon = 0.070
# epoch #127	mean reward = 10.290	epsilon = 0.070
# epoch #128	mean reward = 19.470	epsilon = 0.069
# epoch #129	mean reward = 9.590	epsilon = 0.068
# epoch #130	mean reward = 10.580	epsilon = 0.068
# epoch #131	mean reward = 17.110	epsilon = 0.067
# epoch #132	mean reward = 9.480	epsilon = 0.066
# epoch #133	mean reward = 10.760	epsilon = 0.066
# epoch #134	mean reward = 18.680	epsilon = 0.065
# epoch #135	mean reward = 9.640	epsilon = 0.064
# epoch #136	mean reward = 12.680	epsilon = 0.064
# epoch #137	mean reward = 17.090	epsilon = 0.063
# epoch #138	mean reward = 9.650	epsilon = 0.062
# epoch #139	mean reward = 19.770	epsilon = 0.062
# epoch #140	mean reward = 10.140	epsilon = 0.061
# epoch #141	mean reward = 9.960	epsilon = 0.061
# epoch #142	mean reward = 18.230	epsilon = 0.060
# epoch #143	mean reward = 9.800	epsilon = 0.059
# epoch #144	mean reward = 9.890	epsilon = 0.059
# epoch #145	mean reward = 17.910	epsilon = 0.058
# epoch #146	mean reward = 9.600	epsilon = 0.058
# epoch #147	mean reward = 10.780	epsilon = 0.057
# epoch #148	mean reward = 17.970	epsilon = 0.056
# epoch #149	mean reward = 9.790	epsilon = 0.056
# epoch #150	mean reward = 12.990	epsilon = 0.055
# epoch #151	mean reward = 15.080	epsilon = 0.055
# epoch #152	mean reward = 9.880	epsilon = 0.054
# epoch #153	mean reward = 17.860	epsilon = 0.054
# epoch #154	mean reward = 9.650	epsilon = 0.053
# epoch #155	mean reward = 10.150	epsilon = 0.053
# epoch #156	mean reward = 21.370	epsilon = 0.052
# epoch #157	mean reward = 9.800	epsilon = 0.052
# epoch #158	mean reward = 12.910	epsilon = 0.051
# epoch #159	mean reward = 13.720	epsilon = 0.051
# epoch #160	mean reward = 9.620	epsilon = 0.050
# epoch #161	mean reward = 17.760	epsilon = 0.050
# epoch #162	mean reward = 10.440	epsilon = 0.049
# epoch #163	mean reward = 9.640	epsilon = 0.049
# epoch #164	mean reward = 18.120	epsilon = 0.048
# epoch #165	mean reward = 9.650	epsilon = 0.048
# epoch #166	mean reward = 10.230	epsilon = 0.047
# epoch #167	mean reward = 19.900	epsilon = 0.047
# epoch #168	mean reward = 9.570	epsilon = 0.046
# epoch #169	mean reward = 17.670	epsilon = 0.046
# epoch #170	mean reward = 10.310	epsilon = 0.045
# epoch #171	mean reward = 9.940	epsilon = 0.045
# epoch #172	mean reward = 19.370	epsilon = 0.044
# epoch #173	mean reward = 9.480	epsilon = 0.044
# epoch #174	mean reward = 11.280	epsilon = 0.043
# epoch #175	mean reward = 17.520	epsilon = 0.043
# epoch #176	mean reward = 9.560	epsilon = 0.043
# epoch #177	mean reward = 18.140	epsilon = 0.042
# epoch #178	mean reward = 10.070	epsilon = 0.042
# epoch #179	mean reward = 9.620	epsilon = 0.041
# epoch #180	mean reward = 17.710	epsilon = 0.041
# epoch #181	mean reward = 9.530	epsilon = 0.041
# epoch #182	mean reward = 9.930	epsilon = 0.040
# epoch #183	mean reward = 18.980	epsilon = 0.040
# epoch #184	mean reward = 9.630	epsilon = 0.039
# epoch #185	mean reward = 12.660	epsilon = 0.039
# epoch #186	mean reward = 15.570	epsilon = 0.039
# epoch #187	mean reward = 9.600	epsilon = 0.038
# epoch #188	mean reward = 17.730	epsilon = 0.038
# epoch #189	mean reward = 9.570	epsilon = 0.037
# epoch #190	mean reward = 9.950	epsilon = 0.037
# epoch #191	mean reward = 21.050	epsilon = 0.037
# epoch #192	mean reward = 9.390	epsilon = 0.036
# epoch #193	mean reward = 17.620	epsilon = 0.036
# epoch #194	mean reward = 10.360	epsilon = 0.036
# epoch #195	mean reward = 9.600	epsilon = 0.035
# epoch #196	mean reward = 18.580	epsilon = 0.035
# epoch #197	mean reward = 9.600	epsilon = 0.035
# epoch #198	mean reward = 9.970	epsilon = 0.034
# epoch #199	mean reward = 18.710	epsilon = 0.034
# epoch #200	mean reward = 9.500	epsilon = 0.033
# epoch #201	mean reward = 16.190	epsilon = 0.033
# epoch #202	mean reward = 10.540	epsilon = 0.033
# epoch #203	mean reward = 9.560	epsilon = 0.033
# epoch #204	mean reward = 18.530	epsilon = 0.032
# epoch #205	mean reward = 9.560	epsilon = 0.032
# epoch #206	mean reward = 10.940	epsilon = 0.032
# epoch #207	mean reward = 18.100	epsilon = 0.031
# epoch #208	mean reward = 9.390	epsilon = 0.031
# epoch #209	mean reward = 18.300	epsilon = 0.031
# epoch #210	mean reward = 9.480	epsilon = 0.030
# epoch #211	mean reward = 11.050	epsilon = 0.030
# epoch #212	mean reward = 18.300	epsilon = 0.030
# epoch #213	mean reward = 9.470	epsilon = 0.029
# epoch #214	mean reward = 19.970	epsilon = 0.029
# epoch #215	mean reward = 9.690	epsilon = 0.029
# epoch #216	mean reward = 11.550	epsilon = 0.029
# epoch #217	mean reward = 15.340	epsilon = 0.028
# epoch #218	mean reward = 9.620	epsilon = 0.028
# epoch #219	mean reward = 19.690	epsilon = 0.028
# epoch #220	mean reward = 9.500	epsilon = 0.027
# epoch #221	mean reward = 11.170	epsilon = 0.027
# epoch #222	mean reward = 17.690	epsilon = 0.027
# epoch #223	mean reward = 9.450	epsilon = 0.027
# epoch #224	mean reward = 18.200	epsilon = 0.026
# epoch #225	mean reward = 9.550	epsilon = 0.026
# epoch #226	mean reward = 12.740	epsilon = 0.026
# epoch #227	mean reward = 18.100	epsilon = 0.026
# epoch #228	mean reward = 9.630	epsilon = 0.025
# epoch #229	mean reward = 17.930	epsilon = 0.025
# epoch #230	mean reward = 9.540	epsilon = 0.025
# epoch #231	mean reward = 19.000	epsilon = 0.025
# epoch #232	mean reward = 10.410	epsilon = 0.024
# epoch #233	mean reward = 10.070	epsilon = 0.024
# epoch #234	mean reward = 17.940	epsilon = 0.024
# epoch #235	mean reward = 9.400	epsilon = 0.024
# epoch #236	mean reward = 19.560	epsilon = 0.023
# epoch #237	mean reward = 9.580	epsilon = 0.023
# epoch #238	mean reward = 10.400	epsilon = 0.023
# epoch #239	mean reward = 16.850	epsilon = 0.023
# epoch #240	mean reward = 9.600	epsilon = 0.022
# epoch #241	mean reward = 19.820	epsilon = 0.022
# epoch #242	mean reward = 9.380	epsilon = 0.022
# epoch #243	mean reward = 10.660	epsilon = 0.022
# epoch #244	mean reward = 16.400	epsilon = 0.022
# epoch #245	mean reward = 9.580	epsilon = 0.021
# epoch #246	mean reward = 21.610	epsilon = 0.021
# epoch #247	mean reward = 9.510	epsilon = 0.021
# epoch #248	mean reward = 16.620	epsilon = 0.021
# epoch #249	mean reward = 9.450	epsilon = 0.020
# epoch #250	mean reward = 10.490	epsilon = 0.020
# epoch #251	mean reward = 19.130	epsilon = 0.020
# epoch #252	mean reward = 9.460	epsilon = 0.020
# epoch #253	mean reward = 17.070	epsilon = 0.020
# epoch #254	mean reward = 9.550	epsilon = 0.019
# epoch #255	mean reward = 11.470	epsilon = 0.019
# epoch #256	mean reward = 17.170	epsilon = 0.019
# epoch #257	mean reward = 9.550	epsilon = 0.019
# epoch #258	mean reward = 17.980	epsilon = 0.019
# epoch #259	mean reward = 9.560	epsilon = 0.019
# epoch #260	mean reward = 18.420	epsilon = 0.018
# epoch #261	mean reward = 9.530	epsilon = 0.018
# epoch #262	mean reward = 13.160	epsilon = 0.018
# epoch #263	mean reward = 14.160	epsilon = 0.018
# epoch #264	mean reward = 10.460	epsilon = 0.018
# epoch #265	mean reward = 20.560	epsilon = 0.017
# epoch #266	mean reward = 9.590	epsilon = 0.017
# epoch #267	mean reward = 15.720	epsilon = 0.017
# epoch #268	mean reward = 9.230	epsilon = 0.017
# epoch #269	mean reward = 21.590	epsilon = 0.017
# epoch #270	mean reward = 9.420	epsilon = 0.017
# epoch #271	mean reward = 16.840	epsilon = 0.016
# epoch #272	mean reward = 9.470	epsilon = 0.016
# epoch #273	mean reward = 12.400	epsilon = 0.016
# epoch #274	mean reward = 17.670	epsilon = 0.016
# epoch #275	mean reward = 10.030	epsilon = 0.016
# epoch #276	mean reward = 18.160	epsilon = 0.016
# epoch #277	mean reward = 9.400	epsilon = 0.015
# epoch #278	mean reward = 19.580	epsilon = 0.015
# epoch #279	mean reward = 9.460	epsilon = 0.015
# epoch #280	mean reward = 18.290	epsilon = 0.015
# epoch #281	mean reward = 9.460	epsilon = 0.015
# epoch #282	mean reward = 20.270	epsilon = 0.015
# epoch #283	mean reward = 13.040	epsilon = 0.015
# epoch #284	mean reward = 10.670	epsilon = 0.014
# epoch #285	mean reward = 14.620	epsilon = 0.014
# epoch #286	mean reward = 9.610	epsilon = 0.014
# epoch #287	mean reward = 17.830	epsilon = 0.014
# epoch #288	mean reward = 9.640	epsilon = 0.014
# epoch #289	mean reward = 16.430	epsilon = 0.014
# epoch #290	mean reward = 9.460	epsilon = 0.014
# epoch #291	mean reward = 12.020	epsilon = 0.013
# epoch #292	mean reward = 19.470	epsilon = 0.013
# epoch #293	mean reward = 11.930	epsilon = 0.013
# epoch #294	mean reward = 14.670	epsilon = 0.013
# epoch #295	mean reward = 9.840	epsilon = 0.013
# epoch #296	mean reward = 19.700	epsilon = 0.013
# epoch #297	mean reward = 9.640	epsilon = 0.013
# epoch #298	mean reward = 18.260	epsilon = 0.013
# epoch #299	mean reward = 9.450	epsilon = 0.012
# epoch #300	mean reward = 18.470	epsilon = 0.012
# epoch #301	mean reward = 9.390	epsilon = 0.012
# epoch #302	mean reward = 18.520	epsilon = 0.012
# epoch #303	mean reward = 9.550	epsilon = 0.012
# epoch #304	mean reward = 17.990	epsilon = 0.012
# epoch #305	mean reward = 11.910	epsilon = 0.012
# epoch #306	mean reward = 11.200	epsilon = 0.012
# epoch #307	mean reward = 15.400	epsilon = 0.011
# epoch #308	mean reward = 9.970	epsilon = 0.011
# epoch #309	mean reward = 18.670	epsilon = 0.011
# epoch #310	mean reward = 9.890	epsilon = 0.011
# epoch #311	mean reward = 18.400	epsilon = 0.011
# epoch #312	mean reward = 9.610	epsilon = 0.011
# epoch #313	mean reward = 18.070	epsilon = 0.011
# epoch #314	mean reward = 9.400	epsilon = 0.011
# epoch #315	mean reward = 17.940	epsilon = 0.011
# epoch #316	mean reward = 9.450	epsilon = 0.010
# epoch #317	mean reward = 21.240	epsilon = 0.010
# epoch #318	mean reward = 9.530	epsilon = 0.010
# epoch #319	mean reward = 17.870	epsilon = 0.010
# epoch #320	mean reward = 9.430	epsilon = 0.010
# epoch #321	mean reward = 18.030	epsilon = 0.010
# epoch #322	mean reward = 11.330	epsilon = 0.010
# epoch #323	mean reward = 13.060	epsilon = 0.010
# epoch #324	mean reward = 13.150	epsilon = 0.010
# epoch #325	mean reward = 10.230	epsilon = 0.010
# epoch #326	mean reward = 18.090	epsilon = 0.009
# epoch #327	mean reward = 10.290	epsilon = 0.009
# epoch #328	mean reward = 16.270	epsilon = 0.009
# epoch #329	mean reward = 10.330	epsilon = 0.009
# epoch #330	mean reward = 18.770	epsilon = 0.009
# epoch #331	mean reward = 11.270	epsilon = 0.009
# epoch #332	mean reward = 14.890	epsilon = 0.009
# epoch #333	mean reward = 11.400	epsilon = 0.009
# epoch #334	mean reward = 17.170	epsilon = 0.009
# epoch #335	mean reward = 10.960	epsilon = 0.009
# epoch #336	mean reward = 17.030	epsilon = 0.009
# epoch #337	mean reward = 10.900	epsilon = 0.008
# epoch #338	mean reward = 17.430	epsilon = 0.008
# epoch #339	mean reward = 11.080	epsilon = 0.008
# epoch #340	mean reward = 15.980	epsilon = 0.008
# epoch #341	mean reward = 10.710	epsilon = 0.008
# epoch #342	mean reward = 18.720	epsilon = 0.008
# epoch #343	mean reward = 9.940	epsilon = 0.008
# epoch #344	mean reward = 15.860	epsilon = 0.008
# epoch #345	mean reward = 9.500	epsilon = 0.008
# epoch #346	mean reward = 21.180	epsilon = 0.008
# epoch #347	mean reward = 9.510	epsilon = 0.008
# epoch #348	mean reward = 16.760	epsilon = 0.008
# epoch #349	mean reward = 9.410	epsilon = 0.007
# epoch #350	mean reward = 19.600	epsilon = 0.007
# epoch #351	mean reward = 9.510	epsilon = 0.007
# epoch #352	mean reward = 16.810	epsilon = 0.007
# epoch #353	mean reward = 9.380	epsilon = 0.007
# epoch #354	mean reward = 20.620	epsilon = 0.007
# epoch #355	mean reward = 9.410	epsilon = 0.007
# epoch #356	mean reward = 16.150	epsilon = 0.007
# epoch #357	mean reward = 9.430	epsilon = 0.007
# epoch #358	mean reward = 20.590	epsilon = 0.007
# epoch #359	mean reward = 9.730	epsilon = 0.007
# epoch #360	mean reward = 19.600	epsilon = 0.007
# epoch #361	mean reward = 10.060	epsilon = 0.007
# epoch #362	mean reward = 17.380	epsilon = 0.007
# epoch #363	mean reward = 9.780	epsilon = 0.007
# epoch #364	mean reward = 16.970	epsilon = 0.006
# epoch #365	mean reward = 9.770	epsilon = 0.006
# epoch #366	mean reward = 20.810	epsilon = 0.006
# epoch #367	mean reward = 9.600	epsilon = 0.006
# epoch #368	mean reward = 18.510	epsilon = 0.006
# epoch #369	mean reward = 10.590	epsilon = 0.006
# epoch #370	mean reward = 18.400	epsilon = 0.006
# epoch #371	mean reward = 12.120	epsilon = 0.006
# epoch #372	mean reward = 14.400	epsilon = 0.006
# epoch #373	mean reward = 16.610	epsilon = 0.006
# epoch #374	mean reward = 11.620	epsilon = 0.006
# epoch #375	mean reward = 16.860	epsilon = 0.006
# epoch #376	mean reward = 10.460	epsilon = 0.006
# epoch #377	mean reward = 19.320	epsilon = 0.006
# epoch #378	mean reward = 9.450	epsilon = 0.006
# epoch #379	mean reward = 17.410	epsilon = 0.006
# epoch #380	mean reward = 9.520	epsilon = 0.005
# epoch #381	mean reward = 20.100	epsilon = 0.005
# epoch #382	mean reward = 9.170	epsilon = 0.005
# epoch #383	mean reward = 18.680	epsilon = 0.005
# epoch #384	mean reward = 9.460	epsilon = 0.005
# epoch #385	mean reward = 18.580	epsilon = 0.005
# epoch #386	mean reward = 9.530	epsilon = 0.005
# epoch #387	mean reward = 16.890	epsilon = 0.005
# epoch #388	mean reward = 9.880	epsilon = 0.005
# epoch #389	mean reward = 18.140	epsilon = 0.005
# epoch #390	mean reward = 14.370	epsilon = 0.005
# epoch #391	mean reward = 12.590	epsilon = 0.005
# epoch #392	mean reward = 18.780	epsilon = 0.005
# epoch #393	mean reward = 9.690	epsilon = 0.005
# epoch #394	mean reward = 17.030	epsilon = 0.005
# epoch #395	mean reward = 9.480	epsilon = 0.005
# epoch #396	mean reward = 19.030	epsilon = 0.005
# epoch #397	mean reward = 9.290	epsilon = 0.005
# epoch #398	mean reward = 17.320	epsilon = 0.005
# epoch #399	mean reward = 9.500	epsilon = 0.005
# epoch #400	mean reward = 19.940	epsilon = 0.004
# epoch #401	mean reward = 9.810	epsilon = 0.004
# epoch #402	mean reward = 17.050	epsilon = 0.004
# epoch #403	mean reward = 12.370	epsilon = 0.004
# epoch #404	mean reward = 15.470	epsilon = 0.004
# epoch #405	mean reward = 16.280	epsilon = 0.004
# epoch #406	mean reward = 9.650	epsilon = 0.004
# epoch #407	mean reward = 17.530	epsilon = 0.004
# epoch #408	mean reward = 9.510	epsilon = 0.004
# epoch #409	mean reward = 19.530	epsilon = 0.004
# epoch #410	mean reward = 12.280	epsilon = 0.004
# epoch #411	mean reward = 15.550	epsilon = 0.004
# epoch #412	mean reward = 16.910	epsilon = 0.004
# epoch #413	mean reward = 9.540	epsilon = 0.004
# epoch #414	mean reward = 18.590	epsilon = 0.004
# epoch #415	mean reward = 9.400	epsilon = 0.004
# epoch #416	mean reward = 16.180	epsilon = 0.004
# epoch #417	mean reward = 9.540	epsilon = 0.004
# epoch #418	mean reward = 18.870	epsilon = 0.004
# epoch #419	mean reward = 12.500	epsilon = 0.004
# epoch #420	mean reward = 14.390	epsilon = 0.004
# epoch #421	mean reward = 17.840	epsilon = 0.004
# epoch #422	mean reward = 13.600	epsilon = 0.004
# epoch #423	mean reward = 17.330	epsilon = 0.004
# epoch #424	mean reward = 9.540	epsilon = 0.004
# epoch #425	mean reward = 19.420	epsilon = 0.003
# epoch #426	mean reward = 10.080	epsilon = 0.003
# epoch #427	mean reward = 16.210	epsilon = 0.003
# epoch #428	mean reward = 12.040	epsilon = 0.003
# epoch #429	mean reward = 14.520	epsilon = 0.003
# epoch #430	mean reward = 15.730	epsilon = 0.003
# epoch #431	mean reward = 12.070	epsilon = 0.003
# epoch #432	mean reward = 17.840	epsilon = 0.003
# epoch #433	mean reward = 9.480	epsilon = 0.003
# epoch #434	mean reward = 16.260	epsilon = 0.003
# epoch #435	mean reward = 9.820	epsilon = 0.003
# epoch #436	mean reward = 19.780	epsilon = 0.003
# epoch #437	mean reward = 12.260	epsilon = 0.003
# epoch #438	mean reward = 14.450	epsilon = 0.003
# epoch #439	mean reward = 16.410	epsilon = 0.003
# epoch #440	mean reward = 11.340	epsilon = 0.003
# epoch #441	mean reward = 18.220	epsilon = 0.003
# epoch #442	mean reward = 9.450	epsilon = 0.003
# epoch #443	mean reward = 19.610	epsilon = 0.003
# epoch #444	mean reward = 9.510	epsilon = 0.003
# epoch #445	mean reward = 16.030	epsilon = 0.003
# epoch #446	mean reward = 10.030	epsilon = 0.003
# epoch #447	mean reward = 19.370	epsilon = 0.003
# epoch #448	mean reward = 14.290	epsilon = 0.003
# epoch #449	mean reward = 12.170	epsilon = 0.003
# epoch #450	mean reward = 19.790	epsilon = 0.003
# epoch #451	mean reward = 10.040	epsilon = 0.003
# epoch #452	mean reward = 16.780	epsilon = 0.003
# epoch #453	mean reward = 9.720	epsilon = 0.003
# epoch #454	mean reward = 17.970	epsilon = 0.003
# epoch #455	mean reward = 10.160	epsilon = 0.003
# epoch #456	mean reward = 16.080	epsilon = 0.003
# epoch #457	mean reward = 17.760	epsilon = 0.003
# epoch #458	mean reward = 10.250	epsilon = 0.003
# epoch #459	mean reward = 16.580	epsilon = 0.002
# epoch #460	mean reward = 9.370	epsilon = 0.002
# epoch #461	mean reward = 17.410	epsilon = 0.002
# epoch #462	mean reward = 10.860	epsilon = 0.002
# epoch #463	mean reward = 16.290	epsilon = 0.002
# epoch #464	mean reward = 17.850	epsilon = 0.002
# epoch #465	mean reward = 11.350	epsilon = 0.002
# epoch #466	mean reward = 16.130	epsilon = 0.002
# epoch #467	mean reward = 9.530	epsilon = 0.002
# epoch #468	mean reward = 19.310	epsilon = 0.002
# epoch #469	mean reward = 13.110	epsilon = 0.002
# epoch #470	mean reward = 12.250	epsilon = 0.002
# epoch #471	mean reward = 17.550	epsilon = 0.002
# epoch #472	mean reward = 9.910	epsilon = 0.002
# epoch #473	mean reward = 17.670	epsilon = 0.002
# epoch #474	mean reward = 10.220	epsilon = 0.002
# epoch #475	mean reward = 18.880	epsilon = 0.002
# epoch #476	mean reward = 16.160	epsilon = 0.002
# epoch #477	mean reward = 9.180	epsilon = 0.002
# epoch #478	mean reward = 16.440	epsilon = 0.002
# epoch #479	mean reward = 10.570	epsilon = 0.002
# epoch #480	mean reward = 16.140	epsilon = 0.002
# epoch #481	mean reward = 16.120	epsilon = 0.002
# epoch #482	mean reward = 11.090	epsilon = 0.002
# epoch #483	mean reward = 17.970	epsilon = 0.002
# epoch #484	mean reward = 9.970	epsilon = 0.002
# epoch #485	mean reward = 17.260	epsilon = 0.002
# epoch #486	mean reward = 15.830	epsilon = 0.002
# epoch #487	mean reward = 11.260	epsilon = 0.002
# epoch #488	mean reward = 19.180	epsilon = 0.002
# epoch #489	mean reward = 9.600	epsilon = 0.002
# epoch #490	mean reward = 17.420	epsilon = 0.002
# epoch #491	mean reward = 10.670	epsilon = 0.002
# epoch #492	mean reward = 16.870	epsilon = 0.002
# epoch #493	mean reward = 17.420	epsilon = 0.002
# epoch #494	mean reward = 9.360	epsilon = 0.002
# epoch #495	mean reward = 17.360	epsilon = 0.002
# epoch #496	mean reward = 10.280	epsilon = 0.002
# epoch #497	mean reward = 15.860	epsilon = 0.002
# epoch #498	mean reward = 17.050	epsilon = 0.002
# epoch #499	mean reward = 9.540	epsilon = 0.002
# epoch #500	mean reward = 16.420	epsilon = 0.002
# epoch #501	mean reward = 11.790	epsilon = 0.002
# epoch #502	mean reward = 15.050	epsilon = 0.002
# epoch #503	mean reward = 18.100	epsilon = 0.002
# epoch #504	mean reward = 9.510	epsilon = 0.002
# epoch #505	mean reward = 16.920	epsilon = 0.002
# epoch #506	mean reward = 15.150	epsilon = 0.002
# epoch #507	mean reward = 10.570	epsilon = 0.002
# epoch #508	mean reward = 18.710	epsilon = 0.002
# epoch #509	mean reward = 10.310	epsilon = 0.002
# epoch #510	mean reward = 16.450	epsilon = 0.001
# epoch #511	mean reward = 16.230	epsilon = 0.001
# epoch #512	mean reward = 9.670	epsilon = 0.001
# epoch #513	mean reward = 16.270	epsilon = 0.001
# epoch #514	mean reward = 11.900	epsilon = 0.001
# epoch #515	mean reward = 17.810	epsilon = 0.001
# epoch #516	mean reward = 18.470	epsilon = 0.001
# epoch #517	mean reward = 10.280	epsilon = 0.001
# epoch #518	mean reward = 17.140	epsilon = 0.001
# epoch #519	mean reward = 14.110	epsilon = 0.001
# epoch #520	mean reward = 13.360	epsilon = 0.001
# epoch #521	mean reward = 16.860	epsilon = 0.001
# epoch #522	mean reward = 9.700	epsilon = 0.001
# epoch #523	mean reward = 17.520	epsilon = 0.001
# epoch #524	mean reward = 16.370	epsilon = 0.001
# epoch #525	mean reward = 11.640	epsilon = 0.001
# epoch #526	mean reward = 19.340	epsilon = 0.001
# epoch #527	mean reward = 9.740	epsilon = 0.001
# epoch #528	mean reward = 16.570	epsilon = 0.001
# epoch #529	mean reward = 15.040	epsilon = 0.001
# epoch #530	mean reward = 11.200	epsilon = 0.001
# epoch #531	mean reward = 16.770	epsilon = 0.001
# epoch #532	mean reward = 9.830	epsilon = 0.001
# epoch #533	mean reward = 17.370	epsilon = 0.001
# epoch #534	mean reward = 15.860	epsilon = 0.001
# epoch #535	mean reward = 9.550	epsilon = 0.001
# epoch #536	mean reward = 18.630	epsilon = 0.001
# epoch #537	mean reward = 12.740	epsilon = 0.001
# epoch #538	mean reward = 12.680	epsilon = 0.001
# epoch #539	mean reward = 17.130	epsilon = 0.001
# epoch #540	mean reward = 9.910	epsilon = 0.001
# epoch #541	mean reward = 17.240	epsilon = 0.001
# epoch #542	mean reward = 19.080	epsilon = 0.001
# epoch #543	mean reward = 9.720	epsilon = 0.001
# epoch #544	mean reward = 16.970	epsilon = 0.001
# epoch #545	mean reward = 15.250	epsilon = 0.001
# epoch #546	mean reward = 11.580	epsilon = 0.001
# epoch #547	mean reward = 18.070	epsilon = 0.001
# epoch #548	mean reward = 10.460	epsilon = 0.001
# epoch #549	mean reward = 20.280	epsilon = 0.001
# epoch #550	mean reward = 17.050	epsilon = 0.001
# epoch #551	mean reward = 9.440	epsilon = 0.001
# epoch #552	mean reward = 17.460	epsilon = 0.001
# epoch #553	mean reward = 13.210	epsilon = 0.001
# epoch #554	mean reward = 14.280	epsilon = 0.001
# epoch #555	mean reward = 19.770	epsilon = 0.001
# epoch #556	mean reward = 9.520	epsilon = 0.001
# epoch #557	mean reward = 17.880	epsilon = 0.001
# epoch #558	mean reward = 14.250	epsilon = 0.001
# epoch #559	mean reward = 16.990	epsilon = 0.001
# epoch #560	mean reward = 15.610	epsilon = 0.001
# epoch #561	mean reward = 9.420	epsilon = 0.001
# epoch #562	mean reward = 18.070	epsilon = 0.001
# epoch #563	mean reward = 11.750	epsilon = 0.001
# epoch #564	mean reward = 14.360	epsilon = 0.001
# epoch #565	mean reward = 19.320	epsilon = 0.001
# epoch #566	mean reward = 9.820	epsilon = 0.001
# epoch #567	mean reward = 16.450	epsilon = 0.001
# epoch #568	mean reward = 18.280	epsilon = 0.001
# epoch #569	mean reward = 9.630	epsilon = 0.001
# epoch #570	mean reward = 15.690	epsilon = 0.001
# epoch #571	mean reward = 13.120	epsilon = 0.001
# epoch #572	mean reward = 14.820	epsilon = 0.001
# epoch #573	mean reward = 16.010	epsilon = 0.001
# epoch #574	mean reward = 10.380	epsilon = 0.001
# epoch #575	mean reward = 17.140	epsilon = 0.001
# epoch #576	mean reward = 16.690	epsilon = 0.001
# epoch #577	mean reward = 9.660	epsilon = 0.001
# epoch #578	mean reward = 19.410	epsilon = 0.001
# epoch #579	mean reward = 16.300	epsilon = 0.001
# epoch #580	mean reward = 9.620	epsilon = 0.001
# epoch #581	mean reward = 18.290	epsilon = 0.001
# epoch #582	mean reward = 13.770	epsilon = 0.001
# epoch #583	mean reward = 13.270	epsilon = 0.001
# epoch #584	mean reward = 18.620	epsilon = 0.001
# epoch #585	mean reward = 10.030	epsilon = 0.001
# epoch #586	mean reward = 15.850	epsilon = 0.001
# epoch #587	mean reward = 18.570	epsilon = 0.001
# epoch #588	mean reward = 10.160	epsilon = 0.001
# epoch #589	mean reward = 16.470	epsilon = 0.001
# epoch #590	mean reward = 18.150	epsilon = 0.001
# epoch #591	mean reward = 9.470	epsilon = 0.001
# epoch #592	mean reward = 17.730	epsilon = 0.001
# epoch #593	mean reward = 17.360	epsilon = 0.001
# epoch #594	mean reward = 10.310	epsilon = 0.001
# epoch #595	mean reward = 16.730	epsilon = 0.001
# epoch #596	mean reward = 12.670	epsilon = 0.001
# epoch #597	mean reward = 14.980	epsilon = 0.001
# epoch #598	mean reward = 16.960	epsilon = 0.001
# epoch #599	mean reward = 11.690	epsilon = 0.001
# epoch #600	mean reward = 17.470	epsilon = 0.001
# epoch #601	mean reward = 15.440	epsilon = 0.001
# epoch #602	mean reward = 9.830	epsilon = 0.001
# epoch #603	mean reward = 16.700	epsilon = 0.001
# epoch #604	mean reward = 15.920	epsilon = 0.001
# epoch #605	mean reward = 9.810	epsilon = 0.001
# epoch #606	mean reward = 18.930	epsilon = 0.001
# epoch #607	mean reward = 15.750	epsilon = 0.001
# epoch #608	mean reward = 9.510	epsilon = 0.001
# epoch #609	mean reward = 16.160	epsilon = 0.001
# epoch #610	mean reward = 15.110	epsilon = 0.001
# epoch #611	mean reward = 9.720	epsilon = 0.001
# epoch #612	mean reward = 17.860	epsilon = 0.001
# epoch #613	mean reward = 16.360	epsilon = 0.001
# epoch #614	mean reward = 9.780	epsilon = 0.001
# epoch #615	mean reward = 18.650	epsilon = 0.001
# epoch #616	mean reward = 15.800	epsilon = 0.001
# epoch #617	mean reward = 9.500	epsilon = 0.001
# epoch #618	mean reward = 20.710	epsilon = 0.001
# epoch #619	mean reward = 15.600	epsilon = 0.000
# epoch #620	mean reward = 10.660	epsilon = 0.000
# epoch #621	mean reward = 17.290	epsilon = 0.000
# epoch #622	mean reward = 14.450	epsilon = 0.000
# epoch #623	mean reward = 10.380	epsilon = 0.000
# epoch #624	mean reward = 20.210	epsilon = 0.000
# epoch #625	mean reward = 14.080	epsilon = 0.000
# epoch #626	mean reward = 11.190	epsilon = 0.000
# epoch #627	mean reward = 18.290	epsilon = 0.000
# epoch #628	mean reward = 11.000	epsilon = 0.000
# epoch #629	mean reward = 14.710	epsilon = 0.000
# epoch #630	mean reward = 18.300	epsilon = 0.000
# epoch #631	mean reward = 10.630	epsilon = 0.000
# epoch #632	mean reward = 15.690	epsilon = 0.000
# epoch #633	mean reward = 21.630	epsilon = 0.000
# epoch #634	mean reward = 11.280	epsilon = 0.000
# epoch #635	mean reward = 13.430	epsilon = 0.000
# epoch #636	mean reward = 17.880	epsilon = 0.000
# epoch #637	mean reward = 9.790	epsilon = 0.000
# epoch #638	mean reward = 14.810	epsilon = 0.000
# epoch #639	mean reward = 22.280	epsilon = 0.000
# epoch #640	mean reward = 11.100	epsilon = 0.000
# epoch #641	mean reward = 14.600	epsilon = 0.000
# epoch #642	mean reward = 17.230	epsilon = 0.000
# epoch #643	mean reward = 9.670	epsilon = 0.000
# epoch #644	mean reward = 15.130	epsilon = 0.000
# epoch #645	mean reward = 12.720	epsilon = 0.000
# epoch #646	mean reward = 16.630	epsilon = 0.000
# epoch #647	mean reward = 14.780	epsilon = 0.000
# epoch #648	mean reward = 13.030	epsilon = 0.000
# epoch #649	mean reward = 18.640	epsilon = 0.000
# epoch #650	mean reward = 15.240	epsilon = 0.000
# epoch #651	mean reward = 14.570	epsilon = 0.000
# epoch #652	mean reward = 12.550	epsilon = 0.000
# epoch #653	mean reward = 15.800	epsilon = 0.000
# epoch #654	mean reward = 14.330	epsilon = 0.000
# epoch #655	mean reward = 15.670	epsilon = 0.000
# epoch #656	mean reward = 15.930	epsilon = 0.000
# epoch #657	mean reward = 15.910	epsilon = 0.000
# epoch #658	mean reward = 10.910	epsilon = 0.000
# epoch #659	mean reward = 15.670	epsilon = 0.000
# epoch #660	mean reward = 18.560	epsilon = 0.000
# epoch #661	mean reward = 11.870	epsilon = 0.000
# epoch #662	mean reward = 15.090	epsilon = 0.000
# epoch #663	mean reward = 20.100	epsilon = 0.000
# epoch #664	mean reward = 11.420	epsilon = 0.000
# epoch #665	mean reward = 14.750	epsilon = 0.000
# epoch #666	mean reward = 19.270	epsilon = 0.000
# epoch #667	mean reward = 12.100	epsilon = 0.000
# epoch #668	mean reward = 13.610	epsilon = 0.000
# epoch #669	mean reward = 17.500	epsilon = 0.000
# epoch #670	mean reward = 11.700	epsilon = 0.000
# epoch #671	mean reward = 13.080	epsilon = 0.000
# epoch #672	mean reward = 18.820	epsilon = 0.000
# epoch #673	mean reward = 16.450	epsilon = 0.000
# epoch #674	mean reward = 10.500	epsilon = 0.000
# epoch #675	mean reward = 16.920	epsilon = 0.000
# epoch #676	mean reward = 14.810	epsilon = 0.000
# epoch #677	mean reward = 11.230	epsilon = 0.000
# epoch #678	mean reward = 15.250	epsilon = 0.000
# epoch #679	mean reward = 16.490	epsilon = 0.000
# epoch #680	mean reward = 10.990	epsilon = 0.000
# epoch #681	mean reward = 18.670	epsilon = 0.000
# epoch #682	mean reward = 16.070	epsilon = 0.000
# epoch #683	mean reward = 13.970	epsilon = 0.000
# epoch #684	mean reward = 14.830	epsilon = 0.000
# epoch #685	mean reward = 15.130	epsilon = 0.000
# epoch #686	mean reward = 17.010	epsilon = 0.000
# epoch #687	mean reward = 9.770	epsilon = 0.000
# epoch #688	mean reward = 14.300	epsilon = 0.000
# epoch #689	mean reward = 19.010	epsilon = 0.000
# epoch #690	mean reward = 10.310	epsilon = 0.000
# epoch #691	mean reward = 15.330	epsilon = 0.000
# epoch #692	mean reward = 19.140	epsilon = 0.000
# epoch #693	mean reward = 15.110	epsilon = 0.000
# epoch #694	mean reward = 10.200	epsilon = 0.000
# epoch #695	mean reward = 18.540	epsilon = 0.000
# epoch #696	mean reward = 14.400	epsilon = 0.000
# epoch #697	mean reward = 9.710	epsilon = 0.000
# epoch #698	mean reward = 19.370	epsilon = 0.000
# epoch #699	mean reward = 15.760	epsilon = 0.000
# epoch #700	mean reward = 10.230	epsilon = 0.000
# epoch #701	mean reward = 18.170	epsilon = 0.000
# epoch #702	mean reward = 15.820	epsilon = 0.000
# epoch #703	mean reward = 10.750	epsilon = 0.000
# epoch #704	mean reward = 22.310	epsilon = 0.000
# epoch #705	mean reward = 14.220	epsilon = 0.000
# epoch #706	mean reward = 17.410	epsilon = 0.000
# epoch #707	mean reward = 12.110	epsilon = 0.000
# epoch #708	mean reward = 14.750	epsilon = 0.000
# epoch #709	mean reward = 20.120	epsilon = 0.000
# epoch #710	mean reward = 14.440	epsilon = 0.000
# epoch #711	mean reward = 10.020	epsilon = 0.000
# epoch #712	mean reward = 21.070	epsilon = 0.000
# epoch #713	mean reward = 15.700	epsilon = 0.000
# epoch #714	mean reward = 10.610	epsilon = 0.000
# epoch #715	mean reward = 18.810	epsilon = 0.000
# epoch #716	mean reward = 14.630	epsilon = 0.000
# epoch #717	mean reward = 16.260	epsilon = 0.000
# epoch #718	mean reward = 10.850	epsilon = 0.000
# epoch #719	mean reward = 15.160	epsilon = 0.000
# epoch #720	mean reward = 23.750	epsilon = 0.000
# epoch #721	mean reward = 24.270	epsilon = 0.000
# epoch #722	mean reward = 32.820	epsilon = 0.000
# epoch #723	mean reward = 36.230	epsilon = 0.000
# epoch #724	mean reward = 36.740	epsilon = 0.000
# epoch #725	mean reward = 30.530	epsilon = 0.000
# epoch #726	mean reward = 24.950	epsilon = 0.000
# epoch #727	mean reward = 28.630	epsilon = 0.000
# epoch #728	mean reward = 30.960	epsilon = 0.000
# epoch #729	mean reward = 26.140	epsilon = 0.000
# epoch #730	mean reward = 13.350	epsilon = 0.000
# epoch #731	mean reward = 18.960	epsilon = 0.000
# epoch #732	mean reward = 20.820	epsilon = 0.000
# epoch #733	mean reward = 27.480	epsilon = 0.000
# epoch #734	mean reward = 37.210	epsilon = 0.000
# epoch #735	mean reward = 25.170	epsilon = 0.000
# epoch #736	mean reward = 30.850	epsilon = 0.000
# epoch #737	mean reward = 31.210	epsilon = 0.000
# epoch #738	mean reward = 25.930	epsilon = 0.000
# epoch #739	mean reward = 29.860	epsilon = 0.000
# epoch #740	mean reward = 25.620	epsilon = 0.000
# epoch #741	mean reward = 22.390	epsilon = 0.000
# epoch #742	mean reward = 24.380	epsilon = 0.000
# epoch #743	mean reward = 25.160	epsilon = 0.000
# epoch #744	mean reward = 30.010	epsilon = 0.000
# epoch #745	mean reward = 35.680	epsilon = 0.000
# epoch #746	mean reward = 35.800	epsilon = 0.000
# epoch #747	mean reward = 31.640	epsilon = 0.000
# epoch #748	mean reward = 31.320	epsilon = 0.000
# epoch #749	mean reward = 28.890	epsilon = 0.000
# epoch #750	mean reward = 28.460	epsilon = 0.000
# epoch #751	mean reward = 24.200	epsilon = 0.000
# epoch #752	mean reward = 16.570	epsilon = 0.000
# epoch #753	mean reward = 21.170	epsilon = 0.000
# epoch #754	mean reward = 21.960	epsilon = 0.000
# epoch #755	mean reward = 23.180	epsilon = 0.000
# epoch #756	mean reward = 22.180	epsilon = 0.000
# epoch #757	mean reward = 20.120	epsilon = 0.000
# epoch #758	mean reward = 17.940	epsilon = 0.000
# epoch #759	mean reward = 14.480	epsilon = 0.000
# epoch #760	mean reward = 15.210	epsilon = 0.000
# epoch #761	mean reward = 17.480	epsilon = 0.000
# epoch #762	mean reward = 24.360	epsilon = 0.000
# epoch #763	mean reward = 32.210	epsilon = 0.000
# epoch #764	mean reward = 28.390	epsilon = 0.000
# epoch #765	mean reward = 26.270	epsilon = 0.000
# epoch #766	mean reward = 29.830	epsilon = 0.000
# epoch #767	mean reward = 36.560	epsilon = 0.000
# epoch #768	mean reward = 33.380	epsilon = 0.000
# epoch #769	mean reward = 29.300	epsilon = 0.000
# epoch #770	mean reward = 26.750	epsilon = 0.000
# epoch #771	mean reward = 31.050	epsilon = 0.000
# epoch #772	mean reward = 28.660	epsilon = 0.000
# epoch #773	mean reward = 30.530	epsilon = 0.000
# epoch #774	mean reward = 34.520	epsilon = 0.000
# epoch #775	mean reward = 29.400	epsilon = 0.000
# epoch #776	mean reward = 25.990	epsilon = 0.000
# epoch #777	mean reward = 27.490	epsilon = 0.000
# epoch #778	mean reward = 25.970	epsilon = 0.000
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[54], line 6
#       3 print("epoch #{}\tmean reward = {:.3f}\tepsilon = {:.3f}".format(i, np.mean(session_rewards), epsilon))
#       5 epsilon *= 0.99
# ----> 6 assert epsilon >= 1e-4, "Make sure epsilon is always nonzero during training"
#       8 if np.mean(session_rewards) > 300:
#       9     print("You Win!")
#
# AssertionError: Make sure epsilon is always nonzero during training

# %% [markdown]
# ### How to interpret results
#
#
# Welcome to the f.. world of deep f...n reinforcement learning. Don't expect agent's reward to smoothly go up. Hope for it to go increase eventually. If it deems you worthy.
#
# Seriously though,
# * __ mean reward__ is the average reward per game. For a correct implementation it may stay low for some 10 epochs, then start growing while oscilating insanely and converges by ~50-100 steps depending on the network architecture.
# * If it never reaches target score by the end of for loop, try increasing the number of hidden neurons or look at the epsilon.
# * __ epsilon__ - agent's willingness to explore. If you see that agent's already at < 0.01 epsilon before it's is at least 200, just reset it back to 0.1 - 0.5.

# %% [markdown]
# ### Record videos
#
# As usual, we now use `gym.wrappers.Monitor` to record a video of our agent playing the game. Unlike our previous attempts with state binarization, this time we expect our agent to act ~~(or fail)~~ more smoothly since there's no more binarization error at play.
#
# As you already did with tabular q-learning, we set epsilon=0 for final evaluation to prevent agent from exploring himself to death.

# %%
# Record sessions

import gym.wrappers

with gym.wrappers.Monitor(gym.make("CartPole-v0"), directory="videos", force=True) as env_monitor:
    sessions = [generate_session(env_monitor, epsilon=0.5, train=False) for _ in range(100)]

# %%
# Show video. This may not work in some setups. If it doesn't
# work for you, you can download the videos and view them locally.

from pathlib import Path
from base64 import b64encode
from IPython.display import HTML

video_paths = sorted([s for s in Path('videos').iterdir() if s.suffix == '.mp4'])
video_path = video_paths[-1]  # You can also try other indices

if 'google.colab' in sys.modules:
    # https://stackoverflow.com/a/57378660/1214547
    with video_path.open('rb') as fp:
        mp4 = fp.read()
    data_url = 'data:video/mp4;base64,' + b64encode(mp4).decode()
else:
    data_url = str(video_path)

HTML("""
<video width="640" height="480" controls>
  <source src="{}" type="video/mp4">
</video>
""".format(data_url))
# Out:
# <video width="640" height="480" controls>
#   <source src="videos/openaigym.video.2.122080.video000064.mp4" type="video/mp4">
# </video>
